# %%
import pandas
# %matplotlib inline

# %%
df = pandas.read_csv("./data/20161212_BaseData_AllBuildings.csv", header=0, sep=',')
#df = pandas.read_csv("N:/Python/litix/data/test1.csv", header=0, sep=',')

# %%
df.head()
# Out:
#                            sitename  site_id           building_name  \
# 0                  Demo_Anzac House      462             ANZAC House
# 1            Demo_Ashburner Francis      495         Test Building 1
# 2                   Demo_Blackburne      602   1050 Hay Street Perth
# 3                   Demo_Blackburne      602  Aria Luxury Apartments
# 4  Demo_Burswood Residential Towers      168           Allegro Tower
#
#    building_id   nla                             building_address  post_code  \
# 0      18802.0     0                  28 St Georges Tce- Perth WA     6000.0
# 1      20631.0     0                                          NaN        NaN
# 2      23579.0  2192               1050 Hay Street- West Perth WA     6005.0
# 3      23578.0     0  Cnr Alfred Rd & Milyarn Rise- Swanbourne WA     6010.0
# 4      10490.0     0                    19 The Circus Burswood WA     6100.0
#
#               sector  num_lifts year_built  num_rooms  num_beds
# ...

# %%
import missingno as msno
msno.matrix(df)

# %%
msno.bar(df)

# %%
df_exp = pandas.read_csv("./data/expenses.csv", header=0, sep=',')

# %%
df_exp.head()
# Out:
#                                   site  insurance  carpark_repair_maintenance  \
# 0                       Albany_Central   10094.13                      2400.0
# 1       Primewest_Busselton_Home_Depot   25460.71                     13841.4
# 2  Bunbury_Centrepoint_Shopping_Centre   49946.68                     40437.3
#
#    fire_protection   security   cleaning  gardening  repair_maintenance  \
# 0         24114.90    1095.00    1247.00   13996.38             6156.57
# 1         14974.73        NaN   11133.98   42392.42                 NaN
# 2         87028.46  238025.67  503198.49   79502.50                 NaN
#
#   electricity  audit_fees         ...          music_line_pa  postage_petties  \
# 0    10533.15        2380         ...                    NaN              NaN
# 1     10869.8        3745         ...                    NaN              NaN
# 2  100.977.41        5950         ...                1582.86          2909.37
#
# ...
